# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_sample_image
from sklearn.cluster import KMeans


china = load_sample_image("china.jpg")
image = china /255
plt.imshow(image)

# %%
image_n = image.reshape(image.shape[0]*image.shape[1], image.shape[2])
image_n.shape
# Out:
# (273280, 3)

# %%
kmeans = KMeans(n_clusters=5, random_state=0).fit(image_n)
image2show = kmeans.cluster_centers_[kmeans.labels_]

# %%
cluster_image = pic2show.reshape(image.shape[0], image.shape[1], image.shape[2])
plt.imshow(cluster_image)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-2a30ba656a3a> in <module>()
# ----> 1 cluster_image = pic2show.reshape(image.shape[0], image.shape[1], image.shape[2])
#       2 plt.imshow(cluster_image)
#
# NameError: name 'pic2show' is not defined
